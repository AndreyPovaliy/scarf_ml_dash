# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('data/retro_data.csv')
df
# Out:
#        name   gender  age    bmi       bmi_cat  metatarsalgia  stiffness  \
# 0      id_1  Женский   38  21.06         Норма              0          0
# 1      id_2  Женский   57  25.06  Предожирение              1          0
# 2      id_3  Женский   42  24.83         Норма              0          0
# 3      id_4  Женский   62  27.05  Предожирение              1          0
# 4      id_5  Женский   65  28.97  Предожирение              0          0
# ..      ...      ...  ...    ...           ...            ...        ...
# 308  id_309  Женский   59  21.28         Норма              0          1
# 309  id_310  Женский   49  23.61         Норма              0          0
# 310  id_311  Женский   60  20.92         Норма              0          0
# 311  id_312  Женский   75  25.69  Предожирение              0          0
# 312  id_313  Женский   77  28.07  Предожирение              1          0
#
#      recurrence is_akin  is_additional  ... moxfq_12  fadi_12  faam_12  \
# 0             0     Нет              0  ...    20.00       92       70
# 1             0     Нет              1  ...    26.25       79       69
# 2             0     Нет              0  ...    20.00       98       73
# 3             0      Да              1  ...    55.00      101       79
# 4             0      Да              0  ...    36.25      101       69
# ..          ...     ...            ...  ...      ...      ...      ...
# 308           1     Нет              4  ...    30.00      102       73
# 309           0      Да              0  ...    36.25       98       77
# 310           0      Да              1  ...    37.50       64       76
# 311           0      Да              0  ...    41.25       81       52
# 312           0      Да              2  ...    51.25       99       45
#
#      sefas_12  aofas_24  vasfa_24  moxfq_24  fadi_24  faam_24  sefas_24
# 0          40        96      98.0     18.00       98       70        44
# 1          33        83      90.5     22.25       92       78        35
# 2          27       100     100.0     16.00       94       82        30
# 3          24        84      80.0     49.00       87       74        39
# 4          28        75      92.0     34.25       83       74        36
# ..        ...       ...       ...       ...      ...      ...       ...
# 308        32        77      92.5     28.00       71       69        34
# 309        34        77      90.5     32.25      104       83        33
# 310        35        82      69.5     31.50       79       51        36
# 311        24        66      77.0     39.25       87       82        40
# 312        37        91      82.0     49.25       99       46        27
#
# [313 rows x 55 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313 entries, 0 to 312
# Data columns (total 55 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   name                       313 non-null    object
#  1   gender                     313 non-null    object
#  2   age                        313 non-null    int64
#  3   bmi                        313 non-null    float64
#  4   bmi_cat                    313 non-null    object
#  5   metatarsalgia              313 non-null    int64
#  6   stiffness                  313 non-null    int64
#  7   recurrence                 313 non-null    int64
#  8   is_akin                    313 non-null    object
#  9   is_additional              313 non-null    int64
#  10  initial_deformation_grade  313 non-null    object
#  11  aofas_cat_0                313 non-null    int64
#  12  aofas_0                    313 non-null    int64
#  13  vasfa_0                    313 non-null    float64
#  14  moxfq_0                    313 non-null    float64
#  15  hvipa_0                    313 non-null    float64
#  16  hva_0                      313 non-null    float64
#  17  ima_0                      313 non-null    float64
#  18  imaI_V_0                   313 non-null    float64
#  19  imaIV_V_0                  313 non-null    float64
#  20  dmma_0                     313 non-null    float64
#  21  tsp_0                      313 non-null    int64
#  22  time                       313 non-null    int64
#  23  hvipa_12                   313 non-null    float64
#  24  hva_12                     313 non-null    float64
#  25  ima_12                     313 non-null    float64
#  26  imaI_V_12                  313 non-null    float64
#  27  imaIV_V_12                 313 non-null    float64
#  28  dmma_12                    313 non-null    float64
#  29  tsp_12                     313 non-null    int64
#  30  hvipa_24                   313 non-null    float64
#  31  hva_24                     313 non-null    float64
#  32  ima_24                     313 non-null    float64
#  33  imaI_V_24                  313 non-null    float64
#  34  imaIV_V_24                 313 non-null    float64
#  35  dmma_24                    313 non-null    float64
#  36  tsp_24                     313 non-null    int64
#  37  aofas_6                    313 non-null    int64
#  38  vasfa_6                    313 non-null    float64
#  39  moxfq_6                    313 non-null    float64
#  40  fadi_6                     313 non-null    int64
#  41  faam_6                     313 non-null    int64
#  42  sefas_6                    313 non-null    int64
#  43  aofas_12                   313 non-null    int64
#  44  vasfa_12                   313 non-null    float64
#  45  moxfq_12                   313 non-null    float64
#  46  fadi_12                    313 non-null    int64
#  47  faam_12                    313 non-null    int64
#  48  sefas_12                   313 non-null    int64
#  49  aofas_24                   313 non-null    int64
#  50  vasfa_24                   313 non-null    float64
#  51  moxfq_24                   313 non-null    float64
#  52  fadi_24                    313 non-null    int64
#  53  faam_24                    313 non-null    int64
#  54  sefas_24                   313 non-null    int64
# dtypes: float64(27), int64(23), object(5)
# memory usage: 134.6+ KB

# %%
df = df.drop('name', axis=1)
x = df.drop('metatarsalgia', axis=1)
y = df['metatarsalgia']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42, stratify=y)

# %%
rf = RandomForestClassifier(
    n_estimators=500, 
    max_depth=5, 
    max_features=None, 
    bootstrap=True, 
    min_samples_split=5,
    min_samples_leaf=2, 
    random_state=42,
    class_weight=None,
    verbose=1,
    n_jobs=-1
)

# %%
rf.fit(X_train, y_train)
y_pred_train = rf.predict(X_train)
y_pred_test = rf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/7k/0hthbbf925j5rmfcysr3jss40000gn/T/ipykernel_60445/323415700.py in ?()
# ----> 1 rf.fit(X_train, y_train)
#       2 y_pred_train = rf.predict(X_train)
#       3 y_pred_test = rf.predict(X_test)
#
# ~/Library/Python/3.9/lib/python/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1385                 skip_parameter_validation=(
#    1386                     prefer_skip_nested_validation or global_skip_validation
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#
# ~/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_forest.py in ?(self, X, y, sample_weight)
#     356         # Validate or convert input data
#     357         if issparse(y):
#     358             raise ValueError("sparse multilabel-indicator for y is not supported.")
#     359
# --> 360         X, y = validate_data(
#     361             self,
#     362             X,
#     363             y,
#
# ~/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2957             if "estimator" not in check_y_params:
#    2958                 check_y_params = {**default_check_params, **check_y_params}
#    2959             y = check_array(y, input_name="y", **check_y_params)
#    2960         else:
# -> 2961             X, y = check_X_y(X, y, **check_params)
#    2962         out = X, y
#    2963
#    2964     if not no_val_X and check_params.get("ensure_2d", True):
#
# ~/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1366         )
#    1367
#    1368     ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
#    1369
# -> 1370     X = check_array(
#    1371         X,
#    1372         accept_sparse=accept_sparse,
#    1373         accept_large_sparse=accept_large_sparse,
#
# ~/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1053                     array = xp.astype(array, dtype, copy=False)
#    1054                 else:
#    1055                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1056             except ComplexWarning as complex_warning:
# -> 1057                 raise ValueError(
#    1058                     "Complex data not supported\n{}\n".format(array)
#    1059                 ) from complex_warning
#    1060
#
# ~/Library/Python/3.9/lib/python/site-packages/sklearn/utils/_array_api.py in ?(array, dtype, order, copy, xp, device)
#     835         # Use NumPy API to support order
#     836         if copy is True:
#     837             array = numpy.array(array, order=order, dtype=dtype)
#     838         else:
# --> 839             array = numpy.asarray(array, order=order, dtype=dtype)
#     840
#     841         # At this point array is a NumPy ndarray. We convert it to an array
#     842         # container that is consistent with the input's namespace.
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'Женский'

# %%
rf.predict(X_test)

# %%
print(f'rf train accuracy {accuracy_score(y_train, y_pred_train):.3f}')
print(f'fr test accuracy {accuracy_score(y_test, y_pred_test):.3f}')

# %%
rf.feature_importances_

# %%
rf2 = RandomForestClassifier(
    n_estimators=500, 
    max_depth=3, 
    max_features=3, 
    bootstrap=True, 
    min_samples_split=5,
    min_samples_leaf=2,
    random_state=42,
    class_weight=None,
    verbose=1,
    n_jobs=-1
)

# %%
rf2.fit(X_train, y_train)
y_pred_train = rf2.predict(X_train)
y_pred_test = rf2.predict(X_test)

# %%
print(f'rf train accuracy {accuracy_score(y_train, y_pred_train):.3f}')
print(f'fr test accuracy {accuracy_score(y_test, y_pred_test):.3f}')

# %%
cv_scores = cross_val_score(rf2, X, y, cv=10, scoring='accuracy', n_jobs=-1, verbose=2)

# %%
cv_scores

# %%
sns.boxplot(cv_scores)
plt.show()

# %%
param_grid = {
    'max_depth': [2, 3, 4],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': [2, 3, 4]
}

rf3 = RandomForestClassifier(n_estimators=500, random_state=42)

grid_search = GridSearchCV(estimator=rf3,
                           param_grid=param_grid,
                           cv=5,
                           scoring='accuracy',
                           n_jobs=-1)

# %%
grid_search.fit(X_train, y_train)

# %%
print(grid_search.best_params_)

# %%
print(grid_search.best_score_)
