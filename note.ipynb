# %%
import pandas as pd

# %%
df = pd.read_csv('data/penguins.csv')

# %%
df['species'].isin(["Adelie"])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool
